# %%
import numpy as np
import pandas as pd
import json
import os

from disorder.disorder import Disorder
from disorder.entropy import Entropy

# %%
path='data/Examples/'
list_of_files=os.listdir(path)

# %%
from tqdm import tqdm
from time import time

disordered_comp={}
exc=[]
exc_oxi=[]
exc_large=[]
errors=[]
errors_oxi=[]
errors_large=[]

t1=time()
for i in tqdm(range(len(list_of_files[:-1]))):
    file=list_of_files[i]
    try:
        ent=Entropy(file=path+file,radius_file='data/all_radii.csv')
        ent.get_data()
        compound={}
        compound['formula']=ent.formula
        compound['ICSD_ID']=ent.material.material.read_id
        compound['group_num']=ent.material.material.space_group
        compound['Z']=ent.z
        if(np.nan not in ent.material.element_radiuses()):
            if(len(ent.material.positions)<501):
                orbits=ent.data
                compound=compound|orbits.to_dict()
                ent=Entropy(file=path+file,radius_file='data/all_radii.csv')
                compound['entropy']=ent.calculate_entropy()
                disordered_comp[file]=compound
            else:
                exc_large.append(file)
                errors_large.append(list(set(ent.material.return_errors())))
        else:
            exc_oxi.append(file)
            errors_oxi.append(list(set(ent.material.return_errors())))
                                    
    except:
        exc.append(file)
        errors.append(list(set(ent.material.return_errors())))
t2=time()
print(t2-t1)
# Out:
# 100%|██████████| 26/26 [00:50<00:00,  1.94s/it]
# 50.49496603012085

# %%
with open('disorder_results.json','w') as f:
    json.dump(disordered_comp, f, indent = 4)

# %%
err=pd.DataFrame()
err['id']=exc
err['errors']=errors
err.to_csv('excluded_files.csv')

err=pd.DataFrame()
err['id']=exc_large
err['errors']=errors_large
err.to_csv('files_number_of_sites_larger_500.csv')

err=pd.DataFrame()
err['id']=exc_oxi
err['errors']=errors_oxi
err.to_csv('files_oxidation_errors.csv')

# %%
df=pd.DataFrame.from_dict(disordered_comp,orient='index')

# %%
df
# Out:
#                                                      formula  ICSD_ID  \
# icsd_280085.cif                       Fe0.97 K0.97 O4 Si1.03   280085
# icsd_420708.cif                     Ca1.37 Eu1.63 Ni2 Zn2.93   420708
# icsd_094411.cif                                 As7 Ca2 Co12    94411
# icsd_020759.cif                                   Cs1 I3 Pb1    20759
# icsd_108758.cif                                       Ti1 V1   108758
# icsd_173671.cif                                Cr1 O8 Rb1 S2   173671
# icsd_181418.cif                              Cu0.8 Ga2.4 Se4   181418
# icsd_417840.cif                        Cs3 I12.78 Mo6 Se1.22   417840
# icsd_185333.cif                             Cu3.97 Ga6.94 Y3   185333
# icsd_013796.cif                              Hg1 Na2 Se6 Sn2    13796
# icsd_255747.cif                  Ge0.416 Li10 P2 S12 Sn0.584   255747
# icsd_239274.cif                 K0.3 O3 Ta0.125 V0.125 W0.75   239274
# icsd_153943.cif                               O2 Ti0.6 Zr0.4   153943
# icsd_253699.cif                      Ca0.4 Eu0.1 Gd0.3 O4 W1   253699
# icsd_202039.cif                          Ca0.82 F2.36 Th0.18   202039
# icsd_267271.cif                              Cu8 Ge3 Na4 S12   267271
# icsd_074470.cif                Ca0.97 Co0.199 Mg0.831 O6 Si2    74470
# icsd_040840.cif                         Ca10 Cu3 Mg5 O48 V12    40840
# icsd_236616.cif                        Ca0.4 Co1 Nd0.6 O2.81   236616
# icsd_197006.cif                          Ce0.78 Cu8.8 In3.84   197006
# icsd_091272.cif                                   N2 Ni1 Sr2    91272
# icsd_006319.cif  Al12 Br0.54 Cs6.559 Na4.43 O48 Si12 Zr0.091     6319
# icsd_073976.cif                   Ba0.87 Co3.128 F12 Na3.998    73976
# icsd_028793.cif                            Ce0.7 O1.85 Sm0.3    28793
# icsd_067709.cif                                      Ga2 Te3    67709
#
#                  group_num  Z  \
# icsd_280085.cif        182  2
# icsd_420708.cif         63  4
# icsd_094411.cif        176  1
# icsd_020759.cif         62  4
# icsd_108758.cif        229  1
# icsd_173671.cif        147  1
# icsd_181418.cif        121  2
# icsd_417840.cif        167  6
# icsd_185333.cif         71  2
# icsd_013796.cif        140  4
# icsd_255747.cif        137  2
# icsd_239274.cif        182  6
# icsd_153943.cif         60  4
# icsd_253699.cif         88  4
# icsd_202039.cif        225  4
# icsd_267271.cif        226  8
# icsd_074470.cif         15  4
# icsd_040840.cif        230  2
# icsd_236616.cif         62  4
# icsd_197006.cif        226  8
# icsd_091272.cif        139  2
# icsd_006319.cif        221  1
# icsd_073976.cif        204  2
# icsd_028793.cif        225  4
# icsd_067709.cif        216  1
#
#                                                              label  \
# icsd_280085.cif           {0: 'Fe1Si1', 1: 'O2', 2: 'O1', 3: 'K1'}
# icsd_420708.cif  {0: 'Zn1', 1: 'Eu1Ca1', 2: 'Eu2Ca2', 3: 'Zn2',...
# icsd_094411.cif  {0: 'Co2', 1: 'Ca1', 2: 'As2', 3: 'Co1', 4: 'C...
# icsd_020759.cif   {0: 'I2', 1: 'Cs2', 2: 'I1', 3: 'Cs1', 4: 'Pb1'}
# icsd_108758.cif                                       {0: 'Ti1V1'}
# icsd_173671.cif  {0: 'O2', 1: 'O3', 2: 'Cr1', 3: 'Rb1', 4: 'O1'...
# icsd_181418.cif        {0: 'Ga1', 1: 'Cu2Ga2', 2: 'Cu1', 3: 'Se1'}
# icsd_417840.cif  {0: 'I3', 1: 'I2', 2: 'Cs2', 3: 'Se1', 4: 'I1'...
# icsd_185333.cif  {0: 'Cu2Ga2', 1: 'Y1', 2: 'Cu4Ga4', 3: 'Cu3Ga3...
# icsd_013796.cif  {0: 'Na2', 1: 'Na3', 2: 'Na4', 3: 'Se2', 4: 'S...
# icsd_255747.cif  {0: 'P2', 1: 'Li1', 2: 'S3', 3: 'Ge1Sn1P1', 4:...
# icsd_239274.cif          {0: 'O1', 1: 'K1', 2: 'W1Ta1V1', 3: 'O2'}
# icsd_153943.cif                             {0: 'Zr1Ti1', 1: 'O1'}
# icsd_253699.cif                 {0: 'W1', 1: 'O1', 2: 'Gd1Eu1Ca1'}
# icsd_202039.cif           {0: 'Ca1Th1', 1: 'F1', 2: 'F3', 3: 'F2'}
# icsd_267271.cif  {0: 'S1', 1: 'Na3', 2: 'Cu1', 3: 'Ge1', 4: 'Na...
# icsd_074470.cif  {0: 'Ca1', 1: 'Si1', 2: 'Mg1Co2', 3: 'O2', 4: ...
# icsd_040840.cif       {0: 'Cu1Mg2', 1: 'V1', 2: 'O1', 3: 'Ca1Mg1'}
# icsd_236616.cif   {0: 'Ca1', 1: 'Nd1', 2: 'O2', 3: 'Co1', 4: 'O1'}
# icsd_197006.cif                  {0: 'Ce1', 1: 'Cu2', 2: 'Cu1In1'}
# icsd_091272.cif             {0: 'N2', 1: 'Sr1', 2: 'Ni1', 3: 'N1'}
# icsd_006319.cif  {0: 'Cs4', 1: 'Si1Al1', 2: 'Cs2', 3: 'O2', 4: ...
# icsd_073976.cif      {0: 'Na2Ba1', 1: 'F1', 2: 'Na1', 3: 'Co1Na3'}
# icsd_028793.cif                             {0: 'Sm1Ce1', 1: 'O1'}
# icsd_067709.cif                               {0: 'Ga1', 1: 'Te1'}
#
#                                                            species  \
# icsd_280085.cif  {0: {'Fe3+': 0.485, 'Si4+': 0.515}, 1: {'O2-':...
# icsd_420708.cif  {0: {'Zn0+': 1.0}, 1: {'Eu0+': 0.5758, 'Ca0+':...
# icsd_094411.cif  {0: {'Co0+': 0.46}, 1: {'Ca0+': 1.0}, 2: {'As0...
# icsd_020759.cif  {0: {'I1-': 1.0}, 1: {'Cs1+': 0.013}, 2: {'I1-...
# icsd_108758.cif                     {0: {'Ti0+': 0.5, 'V0+': 0.5}}
# icsd_173671.cif  {0: {'O2-': 0.936}, 1: {'O2-': 0.064}, 2: {'Cr...
# icsd_181418.cif  {0: {'Ga3+': 1.0}, 1: {'Cu1+': 0.283, 'Ga3+': ...
# icsd_417840.cif  {0: {'I1-': 1.0}, 1: {'I1-': 1.0}, 2: {'Cs1+':...
# icsd_185333.cif  {0: {'Cu0+': 0.331, 'Ga0+': 0.58}, 1: {'Y0+': ...
# icsd_013796.cif  {0: {'Na1+': 0.25}, 1: {'Na1+': 0.25}, 2: {'Na...
# icsd_255747.cif  {0: {'P5+': 1.0}, 1: {'Li1+': 0.5}, 2: {'S2-':...
# icsd_239274.cif  {0: {'O2-': 1.0}, 1: {'K1+': 0.45}, 2: {'W5+':...
# icsd_153943.cif   {0: {'Zr4+': 0.4, 'Ti4+': 0.6}, 1: {'O2-': 1.0}}
# icsd_253699.cif  {0: {'W6+': 1.0}, 1: {'O2-': 1.0}, 2: {'Gd3+':...
# icsd_202039.cif  {0: {'Ca2+': 0.82, 'Th4+': 0.18}, 1: {'F1-': 0...
# icsd_267271.cif  {0: {'S2-': 1.0}, 1: {'Na1+': 0.24}, 2: {'Cu1+...
# icsd_074470.cif  {0: {'Ca2+': 0.97}, 1: {'Si4+': 1.0}, 2: {'Mg2...
# icsd_040840.cif  {0: {'Cu2+': 0.375, 'Mg2+': 0.375}, 1: {'V5+':...
# icsd_236616.cif  {0: {'Ca2+': 0.4}, 1: {'Nd3+': 0.6}, 2: {'O2-'...
# icsd_197006.cif  {0: {'Ce0+': 0.767}, 1: {'Cu0+': 0.647}, 2: {'...
# icsd_091272.cif  {0: {'N3-': 0.5}, 1: {'Sr2+': 1.0}, 2: {'Ni2+'...
# icsd_006319.cif  {0: {'Cs1+': 0.09}, 1: {'Si4+': 0.5, 'Al3+': 0...
# icsd_073976.cif  {0: {'Na1+': 0.131, 'Ba2+': 0.869}, 1: {'F1-':...
# icsd_028793.cif  {0: {'Sm3+': 0.3, 'Ce4+': 0.7}, 1: {'O2-': 0.9...
# icsd_067709.cif              {0: {'Ga3+': 0.5}, 1: {'Te2-': 0.75}}
#
#                                                       multiplicity  \
# icsd_280085.cif                           {0: 4, 1: 6, 2: 6, 3: 2}
# icsd_420708.cif               {0: 4, 1: 8, 2: 4, 3: 4, 4: 4, 5: 8}
# icsd_094411.cif               {0: 6, 1: 2, 2: 2, 3: 6, 4: 6, 5: 6}
# icsd_020759.cif                     {0: 4, 1: 4, 2: 8, 3: 4, 4: 4}
# icsd_108758.cif                                             {0: 2}
# icsd_173671.cif               {0: 6, 1: 6, 2: 1, 3: 1, 4: 2, 5: 2}
# icsd_181418.cif                           {0: 2, 1: 4, 2: 2, 3: 8}
# icsd_417840.cif  {0: 36, 1: 36, 2: 36, 3: 12, 4: 12, 5: 18, 6: 36}
# icsd_185333.cif               {0: 2, 1: 2, 2: 4, 3: 8, 4: 8, 5: 4}
# icsd_013796.cif  {0: 8, 1: 8, 2: 8, 3: 8, 4: 16, 5: 4, 6: 8, 7: 8}
# icsd_255747.cif  {0: 2, 1: 16, 2: 8, 3: 4, 4: 8, 5: 8, 6: 8, 7:...
# icsd_239274.cif                          {0: 6, 1: 4, 2: 6, 3: 12}
# icsd_153943.cif                                       {0: 4, 1: 8}
# icsd_253699.cif                                {0: 4, 1: 16, 2: 4}
# icsd_202039.cif                         {0: 4, 1: 8, 2: 32, 3: 32}
# icsd_267271.cif         {0: 96, 1: 48, 2: 64, 3: 24, 4: 24, 5: 96}
# icsd_074470.cif         {0: 4, 1: 8, 2: 4, 3: 8, 4: 4, 5: 8, 6: 8}
# icsd_040840.cif                       {0: 16, 1: 24, 2: 96, 3: 24}
# icsd_236616.cif                     {0: 4, 1: 4, 2: 8, 3: 4, 4: 4}
# icsd_197006.cif                                {0: 8, 1: 8, 2: 96}
# icsd_091272.cif                           {0: 4, 1: 4, 2: 4, 3: 4}
# icsd_006319.cif  {0: 8, 1: 24, 2: 8, 3: 12, 4: 8, 5: 6, 6: 24, ...
# icsd_073976.cif                         {0: 2, 1: 24, 2: 12, 3: 8}
# icsd_028793.cif                                       {0: 4, 1: 8}
# icsd_067709.cif                                       {0: 4, 1: 4}
#
#                                                     Wyckoff_symbol  \
# icsd_280085.cif                   {0: 'f', 1: 'h', 2: 'g', 3: 'b'}
# icsd_420708.cif   {0: 'a', 1: 'f', 2: 'c', 3: 'c', 4: 'c', 5: 'f'}
# icsd_094411.cif   {0: 'h', 1: 'd', 2: 'a', 3: 'h', 4: 'h', 5: 'h'}
# icsd_020759.cif           {0: 'c', 1: 'c', 2: 'd', 3: 'c', 4: 'b'}
# icsd_108758.cif                                           {0: 'a'}
# icsd_173671.cif   {0: 'g', 1: 'g', 2: 'b', 3: 'a', 4: 'd', 5: 'd'}
# icsd_181418.cif                   {0: 'b', 1: 'd', 2: 'a', 3: 'i'}
# icsd_417840.cif  {0: 'f', 1: 'f', 2: 'f', 3: 'c', 4: 'c', 5: 'e...
# icsd_185333.cif   {0: 'c', 1: 'a', 2: 'j', 3: 'm', 4: 'm', 5: 'e'}
# icsd_013796.cif  {0: 'f', 1: 'f', 2: 'f', 3: 'h', 4: 'l', 5: 'b...
# icsd_255747.cif  {0: 'b', 1: 'h', 2: 'g', 3: 'd', 4: 'g', 5: 'g...
# icsd_239274.cif                   {0: 'h', 1: 'e', 2: 'g', 3: 'i'}
# icsd_153943.cif                                   {0: 'c', 1: 'd'}
# icsd_253699.cif                           {0: 'a', 1: 'f', 2: 'b'}
# icsd_202039.cif                   {0: 'a', 1: 'c', 2: 'f', 3: 'f'}
# icsd_267271.cif   {0: 'i', 1: 'f', 2: 'g', 3: 'c', 4: 'd', 5: 'h'}
# icsd_074470.cif  {0: 'e', 1: 'f', 2: 'e', 3: 'f', 4: 'e', 5: 'f...
# icsd_040840.cif                   {0: 'a', 1: 'd', 2: 'h', 3: 'c'}
# icsd_236616.cif           {0: 'c', 1: 'c', 2: 'd', 3: 'b', 4: 'c'}
# icsd_197006.cif                           {0: 'a', 1: 'b', 2: 'i'}
# icsd_091272.cif                   {0: 'e', 1: 'e', 2: 'e', 3: 'e'}
# icsd_006319.cif  {0: 'g', 1: 'k', 2: 'g', 3: 'i', 4: 'g', 5: 'f...
# icsd_073976.cif                   {0: 'a', 1: 'g', 2: 'e', 3: 'c'}
# icsd_028793.cif                                   {0: 'a', 1: 'c'}
# icsd_067709.cif                                   {0: 'c', 1: 'a'}
#
#                                                          occupancy  \
# icsd_280085.cif                {0: 1.0, 1: 0.333, 2: 1.0, 3: 0.97}
# icsd_420708.cif  {0: 1.0, 1: 1.0, 2: 0.962, 3: 1.0, 4: 0.934, 5...
# icsd_094411.cif  {0: 0.46, 1: 1.0, 2: 0.5, 3: 1.0, 4: 0.54, 5: ...
# icsd_020759.cif       {0: 1.0, 1: 0.013, 2: 1.0, 3: 0.989, 4: 1.0}
# icsd_108758.cif                                           {0: 1.0}
# icsd_173671.cif  {0: 0.936, 1: 0.064, 2: 1.0, 3: 1.0, 4: 1.0, 5...
# icsd_181418.cif                {0: 1.0, 1: 0.98, 2: 0.235, 3: 1.0}
# icsd_417840.cif  {0: 1.0, 1: 1.0, 2: 0.422, 3: 0.612, 4: 0.39, ...
# icsd_185333.cif  {0: 0.911, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: ...
# icsd_013796.cif  {0: 0.25, 1: 0.25, 2: 0.25, 3: 1.0, 4: 1.0, 5:...
# icsd_255747.cif  {0: 1.0, 1: 0.5, 2: 1.0, 3: 1.0, 4: 1.0, 5: 0....
# icsd_239274.cif                  {0: 1.0, 1: 0.45, 2: 1.0, 3: 1.0}
# icsd_153943.cif                                   {0: 1.0, 1: 1.0}
# icsd_253699.cif                           {0: 1.0, 1: 1.0, 2: 0.8}
# icsd_202039.cif             {0: 1.0, 1: 0.723, 2: 0.048, 3: 0.064}
# icsd_267271.cif  {0: 1.0, 1: 0.24, 2: 1.0, 3: 1.0, 4: 0.48, 5: ...
# icsd_074470.cif  {0: 0.97, 1: 1.0, 2: 1.0, 3: 1.0, 4: 0.03, 5: ...
# icsd_040840.cif                  {0: 0.75, 1: 1.0, 2: 1.0, 3: 1.0}
# icsd_236616.cif       {0: 0.4, 1: 0.6, 2: 0.938, 3: 1.0, 4: 0.938}
# icsd_197006.cif                       {0: 0.767, 1: 0.647, 2: 1.0}
# icsd_091272.cif                   {0: 0.5, 1: 1.0, 2: 0.5, 3: 0.5}
# icsd_006319.cif  {0: 0.09, 1: 1.0, 2: 0.097, 3: 1.0, 4: 0.258, ...
# icsd_073976.cif                 {0: 1.0, 1: 1.0, 2: 0.5, 3: 0.999}
# icsd_028793.cif                                 {0: 1.0, 1: 0.925}
# icsd_067709.cif                                  {0: 0.5, 1: 0.75}
#
#                                              internal_intersection  \
# icsd_280085.cif            {0: False, 1: True, 2: False, 3: False}
# icsd_420708.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_094411.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_020759.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_108758.cif                                         {0: False}
# icsd_173671.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_181418.cif           {0: False, 1: False, 2: False, 3: False}
# icsd_417840.cif  {0: False, 1: False, 2: True, 3: False, 4: Fal...
# icsd_185333.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_013796.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_255747.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_239274.cif            {0: False, 1: True, 2: False, 3: False}
# icsd_153943.cif                               {0: False, 1: False}
# icsd_253699.cif                     {0: False, 1: False, 2: False}
# icsd_202039.cif             {0: False, 1: False, 2: True, 3: True}
# icsd_267271.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_074470.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_040840.cif           {0: False, 1: False, 2: False, 3: False}
# icsd_236616.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_197006.cif                     {0: False, 1: False, 2: False}
# icsd_091272.cif            {0: False, 1: False, 2: True, 3: False}
# icsd_006319.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_073976.cif            {0: False, 1: False, 2: True, 3: False}
# icsd_028793.cif                               {0: False, 1: False}
# icsd_067709.cif                               {0: False, 1: False}
#
#                                              external_intersection  \
# icsd_280085.cif           {0: False, 1: False, 2: False, 3: False}
# icsd_420708.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_094411.cif  {0: True, 1: False, 2: False, 3: False, 4: Tru...
# icsd_020759.cif   {0: False, 1: True, 2: False, 3: True, 4: False}
# icsd_108758.cif                                         {0: False}
# icsd_173671.cif  {0: True, 1: True, 2: False, 3: False, 4: Fals...
# icsd_181418.cif           {0: False, 1: False, 2: False, 3: False}
# icsd_417840.cif  {0: False, 1: False, 2: True, 3: True, 4: True...
# icsd_185333.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_013796.cif  {0: True, 1: True, 2: True, 3: False, 4: False...
# icsd_255747.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_239274.cif           {0: False, 1: False, 2: False, 3: False}
# icsd_153943.cif                               {0: False, 1: False}
# icsd_253699.cif                     {0: False, 1: False, 2: False}
# icsd_202039.cif              {0: False, 1: True, 2: True, 3: True}
# icsd_267271.cif  {0: False, 1: False, 2: False, 3: False, 4: Fa...
# icsd_074470.cif  {0: True, 1: False, 2: False, 3: False, 4: Tru...
# icsd_040840.cif           {0: False, 1: False, 2: False, 3: False}
# icsd_236616.cif   {0: True, 1: True, 2: False, 3: False, 4: False}
# icsd_197006.cif                     {0: False, 1: False, 2: False}
# icsd_091272.cif             {0: True, 1: False, 2: False, 3: True}
# icsd_006319.cif  {0: True, 1: False, 2: False, 3: False, 4: Tru...
# icsd_073976.cif           {0: False, 1: False, 2: False, 3: False}
# icsd_028793.cif                               {0: False, 1: False}
# icsd_067709.cif                               {0: False, 1: False}
#
#                                                intersecting_orbits  \
# icsd_280085.cif                       {0: [], 1: [], 2: [], 3: []}
# icsd_420708.cif         {0: [], 1: [], 2: [], 3: [], 4: [], 5: []}
# icsd_094411.cif  {0: ['Co3'], 1: [], 2: [], 3: [], 4: ['Co2'], ...
# icsd_020759.cif      {0: [], 1: ['Cs1'], 2: [], 3: ['Cs2'], 4: []}
# icsd_108758.cif                                            {0: []}
# icsd_173671.cif  {0: ['O3'], 1: ['O2'], 2: [], 3: [], 4: [], 5:...
# icsd_181418.cif                       {0: [], 1: [], 2: [], 3: []}
# icsd_417840.cif  {0: [], 1: [], 2: ['Cs1'], 3: ['I1'], 4: ['Se1...
# icsd_185333.cif         {0: [], 1: [], 2: [], 3: [], 4: [], 5: []}
# icsd_013796.cif  {0: ['Na3', 'Na1'], 1: ['Na4', 'Na2'], 2: ['Na...
# icsd_255747.cif  {0: [], 1: [], 2: [], 3: [], 4: [], 5: [], 6: ...
# icsd_239274.cif                       {0: [], 1: [], 2: [], 3: []}
# icsd_153943.cif                                     {0: [], 1: []}
# icsd_253699.cif                              {0: [], 1: [], 2: []}
# icsd_202039.cif     {0: [], 1: ['F3'], 2: ['F1', 'F2'], 3: ['F3']}
# icsd_267271.cif         {0: [], 1: [], 2: [], 3: [], 4: [], 5: []}
# icsd_074470.cif  {0: ['Co1'], 1: [], 2: [], 3: [], 4: ['Ca1'], ...
# icsd_040840.cif                       {0: [], 1: [], 2: [], 3: []}
# icsd_236616.cif      {0: ['Nd1'], 1: ['Ca1'], 2: [], 3: [], 4: []}
# icsd_197006.cif                              {0: [], 1: [], 2: []}
# icsd_091272.cif               {0: ['N1'], 1: [], 2: [], 3: ['N2']}
# icsd_006319.cif  {0: ['Cs3'], 1: [], 2: [], 3: [], 4: ['Cs4', '...
# icsd_073976.cif                       {0: [], 1: [], 2: [], 3: []}
# icsd_028793.cif                                     {0: [], 1: []}
# icsd_067709.cif                                     {0: [], 1: []}
#
#                                          intersect_orbit_connected  \
# icsd_280085.cif   {0: ['Fe1Si1'], 1: ['O2'], 2: ['O1'], 3: ['K1']}
# icsd_420708.cif  {0: ['Zn1'], 1: ['Eu1Ca1'], 2: ['Eu2Ca2'], 3: ...
# icsd_094411.cif  {0: ['Co2', 'Co3'], 1: ['Ca1'], 2: ['As2'], 3:...
# icsd_020759.cif  {0: ['I2'], 1: ['Cs2', 'Cs1'], 2: ['I1'], 3: [...
# icsd_108758.cif                                     {0: ['Ti1V1']}
# icsd_173671.cif  {0: ['O3', 'O2'], 1: ['O3', 'O2'], 2: ['Cr1'],...
# icsd_181418.cif  {0: ['Ga1'], 1: ['Cu2Ga2'], 2: ['Cu1'], 3: ['S...
# icsd_417840.cif  {0: ['I3'], 1: ['I2'], 2: ['Cs2', 'Cs1'], 3: [...
# icsd_185333.cif  {0: ['Cu2Ga2'], 1: ['Y1'], 2: ['Cu4Ga4'], 3: [...
# icsd_013796.cif  {0: ['Na3', 'Na4', 'Na1', 'Na2'], 1: ['Na3', '...
# icsd_255747.cif  {0: ['P2'], 1: ['Li1'], 2: ['S3'], 3: ['Ge1Sn1...
# icsd_239274.cif  {0: ['O1'], 1: ['K1'], 2: ['W1Ta1V1'], 3: ['O2']}
# icsd_153943.cif                         {0: ['Zr1Ti1'], 1: ['O1']}
# icsd_253699.cif           {0: ['W1'], 1: ['O1'], 2: ['Gd1Eu1Ca1']}
# icsd_202039.cif  {0: ['Ca1Th1'], 1: ['F1', 'F3', 'F2'], 2: ['F1...
# icsd_267271.cif  {0: ['S1'], 1: ['Na3'], 2: ['Cu1'], 3: ['Ge1']...
# icsd_074470.cif  {0: ['Co1', 'Ca1'], 1: ['Si1'], 2: ['Mg1Co2'],...
# icsd_040840.cif  {0: ['Cu1Mg2'], 1: ['V1'], 2: ['O1'], 3: ['Ca1...
# icsd_236616.cif  {0: ['Ca1', 'Nd1'], 1: ['Ca1', 'Nd1'], 2: ['O2...
# icsd_197006.cif            {0: ['Ce1'], 1: ['Cu2'], 2: ['Cu1In1']}
# icsd_091272.cif  {0: ['N2', 'N1'], 1: ['Sr1'], 2: ['Ni1'], 3: [...
# icsd_006319.cif  {0: ['Cs4', 'Na1', 'Cs3'], 1: ['Si1Al1'], 2: [...
# icsd_073976.cif  {0: ['Na2Ba1'], 1: ['F1'], 2: ['Na1'], 3: ['Co...
# icsd_028793.cif                         {0: ['Sm1Ce1'], 1: ['O1']}
# icsd_067709.cif                           {0: ['Ga1'], 1: ['Te1']}
#
#                                                     orbit_disorder  entropy
# icsd_280085.cif                  {0: 'S', 1: 'VP', 2: 'O', 3: 'V'}    0.449
# icsd_420708.cif  {0: 'O', 1: 'S', 2: 'SV', 3: 'O', 4: 'V', 5: 'O'}    0.307
# icsd_094411.cif  {0: 'VP', 1: 'O', 2: 'V', 3: 'O', 4: 'VP', 5: ...    0.379
# icsd_020759.cif         {0: 'O', 1: 'VP', 2: 'O', 3: 'VP', 4: 'O'}    0.023
# icsd_108758.cif                                           {0: 'S'}    0.693
# icsd_173671.cif  {0: 'VP', 1: 'VP', 2: 'O', 3: 'O', 4: 'O', 5: ...    0.207
# icsd_181418.cif                  {0: 'O', 1: 'SV', 2: 'V', 3: 'O'}    0.267
# icsd_417840.cif  {0: 'O', 1: 'O', 2: 'VP', 3: 'SVP', 4: 'SVP', ...    0.290
# icsd_185333.cif  {0: 'SV', 1: 'O', 2: 'S', 3: 'S', 4: 'S', 5: 'O'}    0.536
# icsd_013796.cif  {0: 'VP', 1: 'VP', 2: 'VP', 3: 'O', 4: 'O', 5:...    0.378
# icsd_255747.cif  {0: 'O', 1: 'V', 2: 'O', 3: 'S', 4: 'O', 5: 'V...    0.544
# icsd_239274.cif                  {0: 'O', 1: 'VP', 2: 'S', 3: 'O'}    0.260
# icsd_153943.cif                                   {0: 'S', 1: 'O'}    0.224
# icsd_253699.cif                          {0: 'O', 1: 'O', 2: 'SV'}    0.221
# icsd_202039.cif                {0: 'S', 1: 'VP', 2: 'VP', 3: 'VP'}    1.416
# icsd_267271.cif   {0: 'O', 1: 'V', 2: 'O', 3: 'O', 4: 'V', 5: 'V'}    0.337
# icsd_074470.cif  {0: 'SVP', 1: 'O', 2: 'S', 3: 'O', 4: 'SVP', 5...    0.069
# icsd_040840.cif                  {0: 'SV', 1: 'O', 2: 'O', 3: 'S'}    0.180
# icsd_236616.cif       {0: 'SVP', 1: 'SVP', 2: 'V', 3: 'O', 4: 'V'}    0.355
# icsd_197006.cif                           {0: 'V', 1: 'V', 2: 'S'}    0.649
# icsd_091272.cif                {0: 'VP', 1: 'O', 2: 'VP', 3: 'VP'}    0.660
# icsd_006319.cif  {0: 'SVP', 1: 'S', 2: 'V', 3: 'O', 4: 'SVP', 5...    0.388
# icsd_073976.cif                  {0: 'S', 1: 'O', 2: 'VP', 3: 'S'}    0.280
# icsd_028793.cif                                   {0: 'S', 1: 'V'}    0.401
# icsd_067709.cif                                   {0: 'V', 1: 'V'}    1.004
